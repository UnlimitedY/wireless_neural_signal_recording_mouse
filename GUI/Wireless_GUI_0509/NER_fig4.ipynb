# %% [markdown]
# #### NER fig4
# - B. 有无磁场环境在小鼠在静止不动的情况下的频谱的区别
#     - 使用小鼠同一天的数据
#     - 通过IMU的数据进行聚类，得到3类；并分别检测出5s以上的静止片段，分为有无WPT组
#     - 将这些片段的频谱全部画在频谱图上为一个图
#     - 对于3个主要频带能量的显著性对比为一个图

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# sleeping only
natural_behavior_timestamp = {
    "sleeping": ["2025-05-23_11-53-46"],
}

natural_behavior_timestamp_WPT = { # 10min
    "sleeping": ["2025-05-22_20-16-00"]
}
